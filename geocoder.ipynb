# %% [markdown]
# <a href="https://www.kaggle.com/code/udayr007/geocoder?scriptVersionId=151918027" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import folium
from folium import Marker
import warnings
warnings.filterwarnings('ignore')

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent='kaggle_learn')
location = geolocator.geocode("Bangalore")

print(location.point)
print(location.address)
# Out:
# 12 58m 36.457s N, 77 35m 24.2952s E
# Bengaluru, Bangalore North, Bengaluru Urban District, Karnataka, India

# %%
point = location.point
print("Latitude:", point.latitude)
print("Longitude:", point.longitude)
# Out:
# Latitude: 12.9767936
# Longitude: 77.590082

# %%
universities = pd.read_csv("../input/geospatial-learn-course-data/top_universities.csv")
universities.head(10)
# Out:
#                                                Name
# 0                              University of Oxford
# 1                           University of Cambridge
# 2                           Imperial College London
# 3                                        ETH Zurich
# 4                                               UCL
# 5  London School of Economics and Political Science
# 6                           University of Edinburgh
# 7                                        LMU Munich
# 8          École Polytechnique Fédérale de Lausanne
# 9                             King’s College London

# %%
def my_geocoder(row):
    try:
        point = geolocator.geocode(row).point
        return pd.Series({'Latitude': point.latitude, 'Longitude': point.longitude})
    except:
        return None

universities[['Latitude', 'Longitude']] = universities.apply(lambda x: my_geocoder(x['Name']), axis=1)

print("{}% of addresses were geocoded!".format(
    (1 - sum(np.isnan(universities["Latitude"])) / len(universities)) * 100))

# Drop universities that were not successfully geocoded
universities = universities.loc[~np.isnan(universities["Latitude"])]
universities = gpd.GeoDataFrame(
    universities, geometry=gpd.points_from_xy(universities.Longitude, universities.Latitude))
universities.crs = {'init': 'epsg:4326'}
universities.head()
# Out:
# 95.0% of addresses were geocoded!
#                       Name   Latitude   Longitude                     geometry
# 0     University of Oxford  33.650290 -117.828179  POINT (-117.82818 33.65029)
# 1  University of Cambridge  52.210946    0.092005     POINT (0.09200 52.21095)
# 2  Imperial College London  51.498959   -0.175641    POINT (-0.17564 51.49896)
# 3               ETH Zurich  47.413218    8.537491     POINT (8.53749 47.41322)
# 4                      UCL  51.521785   -0.135151    POINT (-0.13515 51.52179)

# %%
# Create a map
m = folium.Map(location=[54, 15], tiles='openstreetmap', zoom_start=2)

# Add points to the map
for idx, row in universities.iterrows():
    Marker([row['Latitude'], row['Longitude']], popup=row['Name']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99952e7d67882d78e6076ee930aeea5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99952e7d67882d78e6076ee930aeea5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99952e7d67882d78e6076ee930aeea5c = L.map(
#                 &quot;map_99952e7d67882d78e6076ee930aeea5c&quot;,
#                 {
#                     center: [54.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0101d6985c4d7019e78c294690665242 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_99952e7d67882d78e6076ee930aeea5c);
#
#
#             var marker_02215567a5de0e6ec49e4cc27b4ce6fd = L.marker(
#                 [33.6502899, -117.8281794],
#                 {}
#             ).addTo(map_99952e7d67882d78e6076ee930aeea5c);
#
#
#         var popup_0b797434ded06628ce5fbc6f60be7532 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_795b9f3a8bb1987aea69133521f2da1f = $(`&lt;div id=&quot;html_795b9f3a8bb1987aea69133521f2da1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Oxford&lt;/div&gt;`)[0];
#                 popup_0b797434ded06628ce5fbc6f60be7532.setContent(html_795b9f3a8bb1987aea69133521f2da1f);
#
#
#
#         marker_02215567a5de0e6ec49e4cc27b4ce6fd.bindPopup(popup_0b797434ded06628ce5fbc6f60be7532)
#         ;
#
#
#
#
#             var marker_c7b2933a2b71d4f308c5d04c750e90f4 = L.marker(
#                 [52.210945550000005, 0.09200497637871279],
#                 {}
#             ).addTo(map_99952e7d67882d78e6076ee930aeea5c);
#
#
#         var popup_22e8638c2eb6a98269cfd7ab8d3c1e27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8441219d039155cc43f3744eeac9d262 = $(`&lt;div id=&quot;html_8441219d039155cc43f3744eeac9d262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Cambridge&lt;/div&gt;`)[0];
#                 popup_22e8638c2eb6a98269cfd7ab8d3c1e27.setContent(html_8441219d039155cc43f3744eeac9d262);
#
#
#
#         marker_c7b2933a2b71d4f308c5d04c750e90f4.bindPopup(popup_22e8638c2eb6a98269cfd7ab8d3c1e27)
#         ;
#
#
#
#
#             var marker_39a67150f6318d2362371ccf7e01c4f3 = L.marker(
#                 [51.4989595, -0.17564069276310426],
#                 {}
#             ).addTo(map_99952e7d67882d78e6076ee930aeea5c);
#
#
#         var popup_860efa4eaa4ac8d8cd65e0b3e3c0bbf5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d15f98fe8ace02f229915dcd835b3eb8 = $(`&lt;div id=&quot;html_d15f98fe8ace02f229915dcd835b3eb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Imperial College London&lt;/div&gt;`)[0];
#                 popup_860efa4eaa4ac8d8cd65e0b3e3c0bbf5.setContent(html_d15f98fe8ace02f229915dcd835b3eb8);
#
#
#
#         marker_39a67150f6318d2362371ccf7e01c4f3.bindPopup(popup_860efa4eaa4ac8d8cd65e0b3e3c0bbf5)
#         ;
#
#
#
#
#             var marker_df922197f5a80eb26c812ae841e6bdc5 = L.marker(
#                 [47.413218, 8.5374914],
#                 {}
#             ).addTo(map_99952e7d67882d78e6076ee930aeea5c);
#
#
#         var popup_3d0b638963ddc00ac6dc287f003664ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_904b35165d52b15cde4f13f8334c43ee = $(`&lt;div id=&quot;html_904b35165d52b15cde4f13f8334c43ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ETH Zurich&lt;/div&gt;`)[0];
#                 popup_3d0b638963ddc00ac6dc287f003664ad.setContent(html_904b35165d52b15cde4f13f8334c43ee);
#
#
#
#         marker_df922197f5a80eb26c812ae841e6bdc5.bindPopup(popup_3d0b638963ddc00ac6dc287f003664ad)
#         ;
#
#
#
#
#             var marker_6f86eb92a67e5f9f9dcfbb96e408d3f1 = L.marker(
#                 [51.5217852, -0.13515149671251314],
#                 {}
#             ).addTo(map_99952e7d67882d78e6076ee930aeea5c);
#
#
#         var popup_8f1a276e66591903d3e45082c8471d0f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d672662da819773f8899a0204a40ba6e = $(`&lt;div id=&quot;html_d672662da819773f8899a0204a40ba6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UCL&lt;/div&gt;`)[0];
#                 popup_8f1a276e66591903d3e45082c8471d0f.setContent(html_d672662da819773f8899a0204a40ba6e);
#
#
#
#         marker_6f86eb92a67e5f9f9dcfbb96e408d3f1.bindPopup(popup_8f1a276e66591903d3e45082c8471d0f)
#         ;
#
#
#
#
#             var marker_ce892087799fa5ca5517d4e8f0ed12c2 = L.marker(

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
europe = world.loc[world.continent == 'Europe'].reset_index(drop=True)

europe_stats = europe[["name", "pop_est", "gdp_md_est"]]
europe_boundaries = europe[["name", "geometry"]]

# %%
europe_boundaries.head()
# Out:
#       name                                           geometry
# 0   Russia  MULTIPOLYGON (((180.00000 71.51571, 180.00000 ...
# 1   Norway  MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...
# 2   France  MULTIPOLYGON (((-51.65780 4.15623, -52.24934 3...
# 3   Sweden  POLYGON ((11.02737 58.85615, 11.46827 59.43239...
# 4  Belarus  POLYGON ((28.17671 56.16913, 29.22951 55.91834...

# %%
europe_stats.head()
# Out:
#       name      pop_est  gdp_md_est
# 0   Russia  144373535.0     1699876
# 1   Norway    5347896.0      403336
# 2   France   67059887.0     2715518
# 3   Sweden   10285453.0      530883
# 4  Belarus    9466856.0       63080

# %%
# Use an attribute join to merge data about countries in Europe
europe = europe_boundaries.merge(europe_stats, on="name")
europe.head()
# Out:
#       name                                           geometry      pop_est  \
# 0   Russia  MULTIPOLYGON (((180.00000 71.51571, 180.00000 ...  144373535.0
# 1   Norway  MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...    5347896.0
# 2   France  MULTIPOLYGON (((-51.65780 4.15623, -52.24934 3...   67059887.0
# 3   Sweden  POLYGON ((11.02737 58.85615, 11.46827 59.43239...   10285453.0
# 4  Belarus  POLYGON ((28.17671 56.16913, 29.22951 55.91834...    9466856.0
#
#    gdp_md_est
# 0     1699876
# 1      403336
# 2     2715518
# 3      530883
# 4       63080
